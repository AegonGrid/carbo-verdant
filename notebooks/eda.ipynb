# %% [markdown]
# # Explore RS data

# %%
import os
import rasterio
import matplotlib.pyplot as plt

# %%
imgs = os.listdir("../data/sentinel_images")

img_name = imgs[0]
print(img_name)

img_path = f"../data/sentinel_images/{img_name}"
# Out:
# ndvi_S2A_MSIL2A_20240624T110641_N0510_R137_T30UWU_20240624T153247.SAFE.tif

# %%
with rasterio.open(img_path) as src:
    img = src.read()

print(img.shape)
# Out:
# (4, 406, 423)

# %%
from PIL import Image

Image.open(img_path)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGBA size=423x406>
